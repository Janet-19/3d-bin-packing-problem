# %%
# %run ./packer.ipynb

# %%
packer = Packer()

packer.add_bin(Bin('small-envelope', 11.5, 6.125, 0.25, 10))
packer.add_bin(Bin('large-envelope', 15.0, 12.0, 0.75, 15))
packer.add_bin(Bin('small-box', 8.625, 5.375, 1.625, 70.0))
packer.add_bin(Bin('medium-box', 11.0, 8.5, 5.5, 70.0))
packer.add_bin(Bin('medium-2-box', 13.625, 11.875, 3.375, 70.0))
packer.add_bin(Bin('large-box', 12.0, 12.0, 5.5, 70.0))
packer.add_bin(Bin('large-2-box', 23.6875, 11.75, 3.0, 70.0))

packer.add_item(Item('50g [powder 1]', 1, 1.9685, 3.9360, 1))
packer.add_item(Item('50g [powder 2]', 1, 1.9685, 3.9360, 2))
packer.add_item(Item('50g [powder 3]', 1, 1.9685, 3.9360, 3))
packer.add_item(Item('50g [powder 4]', 1, 1.9685, 3.9360, 3))
packer.add_item(Item('50g [powder 5]', 1, 1.9685, 3.9360, 3))
packer.add_item(Item('250g [powder 6]', 8.2, 3.9370, 1.9685, 4))
packer.add_item(Item('250g [powder 7]', 8.2, 3.9370, 1.9685, 5))
packer.add_item(Item('250g [powder 8]', 8.2, 3.9370, 1.9685, 6))
packer.add_item(Item('250g [powder 9]', 8.2, 3.9370, 1.9685, 7))
packer.add_item(Item('250g [powder 10]', 8.2, 3.9370, 1.9685, 7))
packer.add_item(Item('180g [powder 11]', 6.5, 2, 1.9685, 7))
packer.add_item(Item('25g [powder 12]', 1.8, 1.5, 0.5, 2))
packer.add_item(Item('25g [powder 13]', 1.8, 1.5, 0.5, 2))
packer.add_item(Item('25g [powder 14]', 2, 1.5, 0.5, 2))
packer.add_item(Item('25g [powder 15]', 2, 1.85, 0.5, 3))
packer.add_item(Item('25g [powder 16]', 2, 1.85, 0.5, 3))
packer.add_item(Item('40g [powder 17]', 3.6, 2.1, 1, 3))
packer.add_item(Item('40g [powder 18]', 3.6, 2.1, 1, 3))
packer.add_item(Item('40g [powder 19]', 3.6, 2.1, 1, 3))
packer.add_item(Item('40g [powder 20]', 3.6, 2.1, 1, 3))
packer.add_item(Item('80g [powder 21]', 4.7, 3.2510, 1.5, 4.5))
packer.add_item(Item('80g [powder 22]', 4.7, 3.2510, 1.5, 4.5))
packer.add_item(Item('80g [powder 23]', 4.7, 3.2510, 1.5, 4.5))
packer.add_item(Item('80g [powder 24]', 4.7, 3.2510, 1.5, 4.5))
packer.add_item(Item('100g [powder 25]', 6.5, 5.5, 1.156, 7))
packer.add_item(Item('100g [powder 26]', 6.5, 4.5, 1.265, 7))
packer.add_item(Item('15g [powder 27]', 0.45, 0.45, 0.2, 1))
packer.add_item(Item('15g [powder 28]', 0.45, 0.45, 0.2, 1))
packer.add_item(Item('15g [powder 29]', 0.45, 0.45, 0.2, 1))
packer.add_item(Item('15g [powder 30]', 0.45, 0.45, 0.2, 1))
packer.add_item(Item('15g [powder 31]', 0.45, 0.45, 0.2, 1))

packer.pack()
# Out:
# ::::::::::: small-envelope(11.500x6.125x0.250, max_weight:10.000) vol(17.609) item_number(5) filling_ratio(0.011)
# FITTED ITEMS:
# ====>  15g [powder 27](0.450x0.450x0.200, weight: 1.000) pos([0, 0, 0]) rt(0) vol(0.040)
# ====>  15g [powder 28](0.450x0.450x0.200, weight: 1.000) pos([Decimal('0.450'), 0, 0]) rt(0) vol(0.040)
# ====>  15g [powder 29](0.450x0.450x0.200, weight: 1.000) pos([0, Decimal('0.450'), 0]) rt(0) vol(0.040)
# ====>  15g [powder 30](0.450x0.450x0.200, weight: 1.000) pos([Decimal('0.900'), 0, 0]) rt(0) vol(0.040)
# ====>  15g [powder 31](0.450x0.450x0.200, weight: 1.000) pos([0, Decimal('0.900'), 0]) rt(0) vol(0.040)
#
# UNFITTED ITEMS:
# ====>  250g [powder 6](8.200x3.937x1.968, weight: 4.000) pos([0, 0, 0]) rt(5) vol(63.534)
# ====>  250g [powder 7](8.200x3.937x1.968, weight: 5.000) pos([0, 0, 0]) rt(5) vol(63.534)
# ====>  250g [powder 8](8.200x3.937x1.968, weight: 6.000) pos([0, 0, 0]) rt(5) vol(63.534)
# ...
